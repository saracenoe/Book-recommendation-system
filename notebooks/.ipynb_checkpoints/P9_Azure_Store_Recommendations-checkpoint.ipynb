# %% [markdown]
# # <font color=red><center>**Store recommendations in Azure Cosmos DB**</center></font>
#
# In ths notebook, we train our best model, run the predictions, and store the results in Azure Cosmos DB.
#
# The recommendations are queried by the Azure Function consumed by Streamlit App.

# %% [markdown]
# ## **<font color=green>Dataset</font>**
# We will work with the Globo.com
#
# The dataset is composed of the following files :
#
# - clicks/clicks/ : contains 385 CSV files
# - clicks_hour_*.csv : contains one hour of clicks on the website
# - articles_embeddings.pickle : pickle file containing the embeddings of the articles
# - articles_metadata.csv : CSV file containing the metadata of the articles

# %% [markdown]
# # <font color=salmon>PART 1 - LIBRARIES, PARAMETERS</font>

# %% [markdown]
# ## **<font color=green>Loading libraries</font>**

# %%
import os
import sys

# Add source directory to python path
sys.path.append(os.path.abspath("../"))

import azure.cosmos
from datetime import datetime
from pathlib import Path
from azure.cosmos import  CosmosClient, PartitionKey, exceptions

import pandas as pd
from implicit.als import AlternatingLeastSquares
from scipy import sparse
from tqdm import tqdm
from dotenv import load_dotenv
import pickle

load_dotenv()
# AZURE_COSMOSDB_URI = os.getenv("AZURE_COSMOSDB_URI")
# AZURE_COSMOSDB_KEY = os.getenv("AZURE_COSMOSDB_KEY")

AZURE_COSMOSDB_URI = os.environ["AZURE_COSMOSDB_URI"]
AZURE_COSMOSDB_KEY = os.environ["AZURE_COSMOSDB_KEY"]

# Plotly as Pandas plotting backend
pd.options.plotting.backend = "plotly"


RAW_DATA_PATH = "../data"

CACHE = dict()

# %%
AZURE_COSMOSDB_URI = "https://recom-books.documents.azure.com:443/"
AZURE_COSMOSDB_KEY = "GF1YfdZed8HIQN3opirxs8RNhswLlEYUKUdvpxNGRSPJXMdMtwfCAHxbIWeiXFP5mZ23hAD9MmwVF6KfnYmCPQ=="

# %%
clicks = pd.concat(
    [
        pd.read_csv(
            click_file_path,
            parse_dates=["session_start", "click_timestamp"],
            date_parser=lambda x: datetime.fromtimestamp(int(int(x) / 1000)),
            dtype={
                "user_id": "category",
                "session_id": "category",
                "session_size": "int",
                "click_article_id": "category",
                "click_environment": "category",
                "click_deviceGroup": "category",
                "click_os": "category",
                "click_country": "category",
                "click_region": "category",
                "click_referrer_type": "category",
            },
        ).replace(
            {
                "click_environment": {
                    "1": "1 - Facebook Instant Article",
                    "2": "2 - Mobile App",
                    "3": "3 - AMP (Accelerated Mobile Pages)",
                    "4": "4 - Web",
                },
                "click_deviceGroup": {
                    "1": "1 - Tablet",
                    "2": "2 - TV",
                    "3": "3 - Empty",
                    "4": "4 - Mobile",
                    "5": "5 - Desktop",
                },
                "click_os": {
                    "1": "1 - Other",
                    "2": "2 - iOS",
                    "3": "3 - Android",
                    "4": "4 - Windows Phone",
                    "5": "5 - Windows Mobile",
                    "6": "6 - Windows",
                    "7": "7 - Mac OS X",
                    "8": "8 - Mac OS",
                    "9": "9 - Samsung",
                    "10": "10 - FireHbbTV",
                    "11": "11 - ATV OS X",
                    "12": "12 - tvOS",
                    "13": "13 - Chrome OS",
                    "14": "14 - Debian",
                    "15": "15 - Symbian OS",
                    "16": "16 - BlackBerry OS",
                    "17": "17 - Firefox OS",
                    "18": "18 - Android",
                    "19": "19 - Brew MP",
                    "20": "20 - Chromecast",
                    "21": "21 - webOS",
                    "22": "22 - Gentoo",
                    "23": "23 - Solaris",
                },
            }
        )
        for click_file_path in tqdm(
            sorted(Path(RAW_DATA_PATH, "clicks/clicks").glob("clicks_hour_*.csv"))
        )
    ],
    sort=False,
    ignore_index=True,
    verify_integrity=True,
)

clicks = clicks.astype(
    {"session_start": "datetime64[ns]", "click_timestamp": "datetime64[ns]"}
)

clicks.describe(include="all", datetime_is_numeric=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 385/385 [00:38<00:00,  9.99it/s]
#         user_id        session_id                  session_start  \
# count   2988181           2988181                        2988181
# unique   322897           1048594                            NaN
# top        5890  1507563657895091                            NaN
# freq       1232               124                            NaN
# mean        NaN               NaN  2017-10-08 16:17:08.013155328
# min         NaN               NaN            2017-10-01 04:37:03
# 25%         NaN               NaN            2017-10-04 15:35:52
# 50%         NaN               NaN            2017-10-08 22:09:00
# 75%         NaN               NaN            2017-10-11 21:16:54
# max         NaN               NaN            2017-10-17 05:36:19
# std         NaN               NaN                            NaN
#
#         session_size click_article_id                click_timestamp  \
# count   2.988181e+06          2988181                        2988181
# unique           NaN            46033                            NaN
# top              NaN           160974                            NaN
# freq             NaN            37213                            NaN
# mean    3.901885e+00              NaN  2017-10-08 16:51:05.070374400
# min     2.000000e+00              NaN            2017-10-01 05:00:00
# 25%     2.000000e+00              NaN            2017-10-04 16:20:52
# 50%     3.000000e+00              NaN            2017-10-08 22:35:30
# 75%     4.000000e+00              NaN            2017-10-11 21:43:24
# max     1.240000e+02              NaN            2017-11-13 21:04:14
# std     3.929941e+00              NaN                            NaN
#
#        click_environment click_deviceGroup         click_os click_country  \
# count            2988181           2988181          2988181       2988181
# unique                 3                 5                8            11
# top              4 - Web        1 - Tablet  17 - Firefox OS             1
# freq             2904478           1823162          1738138       2852406
# mean                 NaN               NaN              NaN           NaN
# min                  NaN               NaN              NaN           NaN
# 25%                  NaN               NaN              NaN           NaN
# 50%                  NaN               NaN              NaN           NaN
# 75%                  NaN               NaN              NaN           NaN
# max                  NaN               NaN              NaN           NaN
# std                  NaN               NaN              NaN           NaN
#
#        click_region click_referrer_type
# count       2988181             2988181
# unique           28                   7
# top              25                   2
# freq         804985             1602601
# mean            NaN                 NaN
# min             NaN                 NaN
# 25%             NaN                 NaN
# 50%             NaN                 NaN
# 75%             NaN                 NaN
# max             NaN                 NaN
# std             NaN                 NaN

# %%
## Create implicit ratings

ratings = (
    clicks.reset_index()
    .groupby(["user_id", "click_article_id"])
    .agg(
        rating=("index", "count"),
    )
    .reset_index()
)
ratings
# Out:
#         user_id click_article_id  rating
# 0             0           157541       1
# 1             0           160158       1
# 2             0           233470       1
# 3             0           313996       1
# 4             0            68866       1
# ...         ...              ...     ...
# 2950705   99998            64329       1
# 2950706   99999           168784       1
# 2950707   99999           225055       1
# 2950708   99999           272143       1
# 2950709   99999            50644       1
#
# [2950710 rows x 3 columns]

# %%
## Create implicit ratings sparse matrix

ratings_sparse = sparse.csr_matrix(
    (
        ratings["rating"],
        (ratings["user_id"].astype("int"), ratings["click_article_id"].astype("int")),
    ),
)

ratings_sparse
# Out:
# <322897x364047 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2950710 stored elements in Compressed Sparse Row format>

# %%
## Train ALS model

model = AlternatingLeastSquares()
model.fit(ratings_sparse)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
## Test ALS model

model.recommend(11183, ratings_sparse[11183], N=5)
# Out:
# (array([160474, 119592,  96663,  64409, 108854]),
#  array([0.26486713, 0.18765613, 0.12838125, 0.05783352, 0.05732467],
#        dtype=float32))

# %%
# Save the model to disk
pickle.dump(model, open('model_implicit.pkl', 'wb'))

# %%
from azure.cosmos import  CosmosClient, PartitionKey #exceptions,

# %%
## Create CosmosDB client and database

client = CosmosClient(AZURE_COSMOSDB_URI, AZURE_COSMOSDB_KEY)
database = client.create_database_if_not_exists(id="Recommendation")
container = database.create_container_if_not_exists(
    id="UserArticles",
    partition_key=PartitionKey(path="/id"),
)

# %%
## Insert recommendations into CosmosDB
# client = CosmosClient(AZURE_COSMOSDB_URI, AZURE_COSMOSDB_KEY)
# database = client.GetDatabase("Recommendation")
# container = database.GetContainer("UserArticles");

user_ids = ratings["user_id"].unique().astype("int")
recos, _ = model.recommend(user_ids, ratings_sparse[user_ids], N=5)

for i, user_id in tqdm(enumerate(user_ids)):
    container.upsert_item(
        body={
            "id": str(user_id),
            "articles": [str(article_id) for article_id in recos[i]],
        }
    )
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# Cell In [12], line 2
#       1 ## Insert recommendations into CosmosDB
# ----> 2 client = CosmosClient(AZURE_COSMOSDB_URI, AZURE_COSMOSDB_KEY)
#       3 database = client.GetDatabase("Recommendation")
#       4 container = database.GetContainer("UserArticles");
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\cosmos_client.py:179, in CosmosClient.__init__(self, url, credential, consistency_level, **kwargs)
#     177 auth = _build_auth(credential)
#     178 connection_policy = _build_connection_policy(kwargs)
# --> 179 self.client_connection = CosmosClientConnection(
#     180     url, auth=auth, consistency_level=consistency_level, connection_policy=connection_policy, **kwargs
#     181 )
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_cosmos_client_connection.py:209, in CosmosClientConnection.__init__(self, url_connection, auth, connection_policy, consistency_level, **kwargs)
#     206 # Routing map provider
#     207 self._routing_map_provider = routing_map_provider.SmartRoutingMapProvider(self)
# --> 209 database_account = self._global_endpoint_manager._GetDatabaseAccount(**kwargs)
#     210 self._global_endpoint_manager.force_refresh(database_account)
#     212 # Use database_account if no consistency passed in to verify consistency level to be used
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_global_endpoint_manager.py:124, in _GlobalEndpointManager._GetDatabaseAccount(self, **kwargs)
#     117 """Gets the database account.
#     118
#     119 First tries by using the default endpoint, and if that doesn't work,
#     120 use the endpoints for the preferred locations in the order they are
#     121 specified, to get the database account.
#     122 """
#     123 try:
# --> 124     database_account = self._GetDatabaseAccountStub(self.DefaultEndpoint, **kwargs)
#     125     return database_account
#     126 # If for any reason(non-globaldb related), we are not able to get the database
#     127 # account from the above call to GetDatabaseAccount, we would try to get this
#     128 # information from any of the preferred locations that the user might have
#     129 # specified (by creating a locational endpoint) and keeping eating the exception
#     130 # until we get the database account and return None at the end, if we are not able
#     131 # to get that info from any endpoints
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_global_endpoint_manager.py:148, in _GlobalEndpointManager._GetDatabaseAccountStub(self, endpoint, **kwargs)
#     143 def _GetDatabaseAccountStub(self, endpoint, **kwargs):
#     144     """Stub for getting database account from the client.
#     145
#     146     This can be used for mocking purposes as well.
#     147     """
# --> 148     return self.Client.GetDatabaseAccount(endpoint, **kwargs)
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_cosmos_client_connection.py:2054, in CosmosClientConnection.GetDatabaseAccount(self, url_connection, **kwargs)
#    2051 headers = base.GetHeaders(self, initial_headers, "get", "", "", "", {})  # path  # id  # type
#    2053 request_params = _request_object.RequestObject("databaseaccount", documents._OperationType.Read, url_connection)
# -> 2054 result, self.last_response_headers = self.__Get("", request_params, headers, **kwargs)
#    2055 database_account = documents.DatabaseAccount()
#    2056 database_account.DatabasesLink = "/dbs/"
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_cosmos_client_connection.py:2248, in CosmosClientConnection.__Get(self, path, request_params, req_headers, **kwargs)
#    2235 """Azure Cosmos 'GET' http request.
#    2236
#    2237 :params str url:
#    (...)
#    2245
#    2246 """
#    2247 request = self.pipeline_client.get(url=path, headers=req_headers)
# -> 2248 return synchronized_request.SynchronizedRequest(
#    2249     client=self,
#    2250     request_params=request_params,
#    2251     global_endpoint_manager=self._global_endpoint_manager,
#    2252     connection_policy=self.connection_policy,
#    2253     pipeline_client=self.pipeline_client,
#    2254     request=request,
#    2255     request_data=None,
#    2256     **kwargs
#    2257 )
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_synchronized_request.py:206, in SynchronizedRequest(client, request_params, global_endpoint_manager, connection_policy, pipeline_client, request, request_data, **kwargs)
#     203     request.headers[http_constants.HttpHeaders.ContentLength] = 0
#     205 # Pass _Request function with it's parameters to retry_utility's Execute method that wraps the call with retries
# --> 206 return _retry_utility.Execute(
#     207     client,
#     208     global_endpoint_manager,
#     209     _Request,
#     210     request_params,
#     211     connection_policy,
#     212     pipeline_client,
#     213     request,
#     214     **kwargs
#     215 )
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_retry_utility.py:77, in Execute(client, global_endpoint_manager, function, *args, **kwargs)
#      75 start_time = time.time()
#      76 if args:
# ---> 77     result = ExecuteFunction(function, global_endpoint_manager, *args, **kwargs)
#      78 else:
#      79     result = ExecuteFunction(function, *args, **kwargs)
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_retry_utility.py:136, in ExecuteFunction(function, *args, **kwargs)
#     133 def ExecuteFunction(function, *args, **kwargs):
#     134     """Stub method so that it can be used for mocking purposes as well.
#     135     """
# --> 136     return function(*args, **kwargs)
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_synchronized_request.py:131, in _Request(global_endpoint_manager, request_params, connection_policy, pipeline_client, request, **kwargs)
#     122     response = _PipelineRunFunction(
#     123         pipeline_client,
#     124         request,
#    (...)
#     128         **kwargs
#     129     )
#     130 else:
# --> 131     response = _PipelineRunFunction(
#     132         pipeline_client,
#     133         request,
#     134         connection_timeout=connection_timeout,
#     135         # If SSL is disabled, verify = false
#     136         connection_verify=kwargs.pop("connection_verify", is_ssl_enabled),
#     137         **kwargs
#     138     )
#     140 response = response.http_response
#     141 headers = dict(response.headers)
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_synchronized_request.py:172, in _PipelineRunFunction(pipeline_client, request, **kwargs)
#     169 def _PipelineRunFunction(pipeline_client, request, **kwargs):
#     170     # pylint: disable=protected-access
# --> 172     return pipeline_client._pipeline.run(request, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:211, in Pipeline.run(self, request, **kwargs)
#     203 pipeline_request = PipelineRequest(
#     204     request, context
#     205 )  # type: PipelineRequest[HTTPRequestType]
#     206 first_node = (
#     207     self._impl_policies[0]
#     208     if self._impl_policies
#     209     else _TransportRunner(self._transport)
#     210 )
# --> 211 return first_node.send(pipeline_request)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 71 (1 times)]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_retry_utility.py:208, in ConnectionRetryPolicy.send(self, request)
#     206             self.sleep(retry_settings, request.context.transport)
#     207             continue
# --> 208     raise err
#     209 finally:
#     210     end_time = time.time()
#
# File ~\miniconda3\envs\gpu7\lib\site-packages\azure\cosmos\_retry_utility.py:185, in ConnectionRetryPolicy.send(self, request)
#     182 start_time = time.time()
#     183 _configure_timeout(request, absolute_timeout, per_request_timeout)
# --> 185 response = self.next.send(request)
#     186 if self.is_retry(retry_settings, response):
#     187     retry_active = self.increment(retry_settings, response=response)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 71 (1 times)]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:71, in _SansIOHTTPPolicyRunner.send(self, request)
#      69 _await_result(self._policy.on_request, request)
#      70 try:
# ---> 71     response = self.next.send(request)
#      72 except Exception:  # pylint: disable=broad-except
#      73     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\_base.py:103, in _TransportRunner.send(self, request)
#      93 def send(self, request):
#      94     """HTTP transport send method.
#      95
#      96     :param request: The PipelineRequest object.
#    (...)
#      99     :rtype: ~azure.core.pipeline.PipelineResponse
#     100     """
#     101     return PipelineResponse(
#     102         request.http_request,
# --> 103         self._sender.send(request.http_request, **request.context.options),
#     104         context=request.context,
#     105     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\azure\core\pipeline\transport\_requests_basic.py:361, in RequestsTransport.send(self, request, **kwargs)
#     358     error = ServiceRequestError(err, error=err)
#     360 if error:
# --> 361     raise error
#     362 if _is_rest(request):
#     363     from azure.core.rest._requests_basic import RestRequestsTransportResponse
#
# ServiceRequestError: <urllib3.connection.HTTPSConnection object at 0x0000024656982920>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
